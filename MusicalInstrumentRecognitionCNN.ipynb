# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras

DATA_PATH = "data.json"

def load_data(data_path):
    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    z = np.array(data["mapping"])
    
    return X, y, z

def prepare_datasets(test_size, validation_size):
    X, y,z = load_data(DATA_PATH)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    return X_train, X_validation, X_test, y_train, y_validation, y_test

#architecture for instrument recogition using CNN -> 2D convolutional layers as input is (T, MFCC)
def build_model(input_shape):
    model = keras.Sequential()
    model.add(keras.layers.Conv2D(32, (3,3), activation="relu", input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3,3), strides=(2,2), padding="same"))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Conv2D(32, (3,3), activation="relu"))
    model.add(keras.layers.MaxPooling2D((3,3), strides=(2,2), padding="same"))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Conv2D(32, (2,2), activation="relu"))
    model.add(keras.layers.MaxPooling2D((2,2), strides=(2,2), padding="same"))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation="relu"))
    model.add(keras.layers.Dropout(0.3))
    model.add(keras.layers.Dense(6, activation="softmax")) #6 classes
    return model

def predict(model, X, y, z):
    X = X[np.newaxis, ...]
    prediction = model.predict(X)
    predicted_index = np.argmax(prediction, axis=1)
    # print("Expected instrument: {}, predicted instrument: {}".format(z[y], z[predicted_index]))
    
if __name__ == "__main__":
    X,y,z = load_data(DATA_PATH)
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    input_shape = (X_train.shape[1], X_train.shape[2], 1) # Time_Bins, 13, 1; 1 for mono channel
    model = build_model(input_shape)
    optimizer = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    # model.summary()
    model.fit(X_train, y_train, validation_data = (X_validation, y_validation), batch_size=32, epochs=30)
    test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
    print(f"Test error: {test_error}, test accuracy: {test_accuracy}")
# Out:
# WARNING:tensorflow:From c:\Users\Satvi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\Satvi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Satvi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Epoch 1/30
# WARNING:tensorflow:From c:\Users\Satvi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Satvi\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 452/452 [==============================] - 4s 5ms/step - loss: 1.4574 - accuracy: 0.4448 - val_loss: 1.0308 - val_accuracy: 0.6589
# Epoch 2/30
# 452/452 [==============================] - 2s 5ms/step - loss: 1.0384 - accuracy: 0.6353 - val_loss: 0.8302 - val_accuracy: 0.7267
# Epoch 3/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.9064 - accuracy: 0.6863 - val_loss: 0.7429 - val_accuracy: 0.7491
# Epoch 4/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.8402 - accuracy: 0.7091 - val_loss: 0.6872 - val_accuracy: 0.7657
# Epoch 5/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.7784 - accuracy: 0.7286 - val_loss: 0.6436 - val_accuracy: 0.7817
# Epoch 6/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.7368 - accuracy: 0.7425 - val_loss: 0.6306 - val_accuracy: 0.7853
# Epoch 7/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.7175 - accuracy: 0.7467 - val_loss: 0.5935 - val_accuracy: 0.8017
# Epoch 8/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.6879 - accuracy: 0.7598 - val_loss: 0.5907 - val_accuracy: 0.7939
# Epoch 9/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.6615 - accuracy: 0.7694 - val_loss: 0.5588 - val_accuracy: 0.8105
# Epoch 10/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.6510 - accuracy: 0.7740 - val_loss: 0.5497 - val_accuracy: 0.8105
# Epoch 11/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.6157 - accuracy: 0.7850 - val_loss: 0.5393 - val_accuracy: 0.8160
# Epoch 12/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.6114 - accuracy: 0.7880 - val_loss: 0.5231 - val_accuracy: 0.8221
# Epoch 13/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.5896 - accuracy: 0.7967 - val_loss: 0.5253 - val_accuracy: 0.8219
# Epoch 14/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.5760 - accuracy: 0.7952 - val_loss: 0.5324 - val_accuracy: 0.8185
# Epoch 15/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.5676 - accuracy: 0.8028 - val_loss: 0.4915 - val_accuracy: 0.8315
# Epoch 16/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.5516 - accuracy: 0.8039 - val_loss: 0.4806 - val_accuracy: 0.8290
# Epoch 17/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.5394 - accuracy: 0.8098 - val_loss: 0.4760 - val_accuracy: 0.8343
# Epoch 18/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.5370 - accuracy: 0.8123 - val_loss: 0.4693 - val_accuracy: 0.8357
# Epoch 19/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.5238 - accuracy: 0.8192 - val_loss: 0.4655 - val_accuracy: 0.8365
# Epoch 20/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.5115 - accuracy: 0.8222 - val_loss: 0.4835 - val_accuracy: 0.8282
# Epoch 21/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.4997 - accuracy: 0.8270 - val_loss: 0.4556 - val_accuracy: 0.8390
# Epoch 22/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.4906 - accuracy: 0.8301 - val_loss: 0.4614 - val_accuracy: 0.8382
# Epoch 23/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.4850 - accuracy: 0.8315 - val_loss: 0.4585 - val_accuracy: 0.8459
# Epoch 24/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.4806 - accuracy: 0.8323 - val_loss: 0.4558 - val_accuracy: 0.8390
# Epoch 25/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.4666 - accuracy: 0.8359 - val_loss: 0.4619 - val_accuracy: 0.8437
# Epoch 26/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.4564 - accuracy: 0.8402 - val_loss: 0.4337 - val_accuracy: 0.8487
# Epoch 27/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.4509 - accuracy: 0.8459 - val_loss: 0.4792 - val_accuracy: 0.8313
# Epoch 28/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.4479 - accuracy: 0.8416 - val_loss: 0.4201 - val_accuracy: 0.8531
# Epoch 29/30
# 452/452 [==============================] - 2s 5ms/step - loss: 0.4429 - accuracy: 0.8429 - val_loss: 0.4208 - val_accuracy: 0.8470
# Epoch 30/30
# 452/452 [==============================] - 2s 4ms/step - loss: 0.4400 - accuracy: 0.8450 - val_loss: 0.4236 - val_accuracy: 0.8512
# 189/189 [==============================] - 0s 2ms/step - loss: 0.4388 - accuracy: 0.8440
# Test error: 0.43882042169570923, test accuracy: 0.8439834117889404
